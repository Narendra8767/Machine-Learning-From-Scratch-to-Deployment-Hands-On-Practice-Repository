# %%
import pickle
import numpy as np
pipe = pickle.load(open('70pipe.pkl','rb'))
# Assume user input
#
test_input2 = np.array([10.7,0.350,0.53,2.60,0.070,5.0,16.0,0.99720,3.15,0.65,11.0],dtype=object).reshape(1,11)
pipe.predict(test_input2)
# Out:
# C:\Users\narendra tekale\anaconda3\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([6], dtype=int64)
