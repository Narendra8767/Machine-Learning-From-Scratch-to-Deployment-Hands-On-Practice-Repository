# %%
import pandas as pd
import numpy as np

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.compose import ColumnsTranfomer
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 4
#       2 from sklearn.preprocessing import OneHotEncoder
#       3 from sklearn.preprocessing import MinMaxScaler
# ----> 4 from sklearn.compose import ColumnsTranfomer
#
# ImportError: cannot import name 'ColumnsTranfomer' from 'sklearn.compose' (C:\Users\narendra tekale\anaconda3\lib\site-packages\sklearn\compose\__init__.py)
