# %% [markdown]
# # this topic is remaining not

# %%
import graphviz.backend as be

# %%
from sklearn.datasets import *
from dtreeviz.trees import *
from IPython.display import Image, display_svg, SVG

# %%
pip install graphviz
# Out:
# Requirement already satisfied: graphviz in c:\users\narendra tekale\anaconda3\lib\site-packages (0.20.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
clas = tree.DecisionTreeClassifier(max_depth=3)  
iris = load_iris()

X_train = iris.data
y_train = iris.target
clas.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
from sklearn.tree import plot_tree
plot_tree(clas)
# Out:
# [Text(0.375, 0.875, 'x[3] <= 0.8\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(0.25, 0.625, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(0.5, 0.625, 'x[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(0.25, 0.375, 'x[2] <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(0.125, 0.125, 'gini = 0.041\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(0.375, 0.125, 'gini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.75, 0.375, 'x[2] <= 4.85\ngini = 0.043\nsamples = 46\nvalue = [0, 1, 45]'),
#  Text(0.625, 0.125, 'gini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.875, 0.125, 'gini = 0.0\nsamples = 43\nvalue = [0, 0, 43]')]

# %% [markdown]
# # 1.Classification

# %%
viz = dtreeviz(clas, 
               X_train,
               y_train,
               feature_names=iris.feature_names, 
               class_names=["setosa", "versicolor", "virginica"])
viz
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 viz = dtreeviz(clas,
#       2                X_train,
#       3                y_train,
#       4                feature_names=iris.feature_names,
#       5                class_names=["setosa", "versicolor", "virginica"])
#       6 viz
#
# NameError: name 'dtreeviz' is not defined

# %%
from sklearn.datasets import *
from sklearn import tree
from dtreeviz.trees import *
from IPython.core.display import display, HTML

classifier = tree.DecisionTreeClassifier(max_depth=4)
cancer = load_breast_cancer()

classifier.fit(cancer.data, cancer.target)
viz = dtreeviz(classifier,
               cancer.data,
               cancer.target,
               target_name='cancer',
               feature_names=cancer.feature_names, 
               class_names=["malignant", "benign"],
               fancy=False) 

display(HTML(viz.svg()))
# Out:
# C:\Users\narendra tekale\AppData\Local\Temp\ipykernel_24712\51308475.py:4: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 10
#       7 cancer = load_breast_cancer()
#       9 classifier.fit(cancer.data, cancer.target)
# ---> 10 viz = dtreeviz(classifier,
#      11                cancer.data,
#      12                cancer.target,
#      13                target_name='cancer',
#      14                feature_names=cancer.feature_names,
#      15                class_names=["malignant", "benign"],
#      16                fancy=False)
#      18 display(HTML(viz.svg()))
#
# NameError: name 'dtreeviz' is not defined

# %% [markdown]
# ## 2.Regression

# %%
regr = tree.DecisionTreeRegressor(max_depth=4)
boston = load_boston()
X_train = boston.data
y_train = boston.target
regr.fit(X_train, y_train)

viz = dtreeviz(regr,
               X_train,
               y_train,
               target_name='price',
               feature_names=boston.feature_names,
               scale=2
              )
viz
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 regr = tree.DecisionTreeRegressor(max_depth=4)
# ----> 2 boston = load_boston()
#       3 X_train = boston.data
#       4 y_train = boston.target
#
# NameError: name 'load_boston' is not defined
