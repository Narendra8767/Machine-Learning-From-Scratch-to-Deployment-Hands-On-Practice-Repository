# %%
import pandas as pd
import seaborn as sns

# %%
tips=sns.load_dataset('tips')

# %%
titanic = pd.read_csv('data/Titanic-Train-Data.csv')

# %%
iris = pd.read_csv('data/Iris.csv')

# %%
tips.sample(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 122       14.26  2.50    Male     No  Thur   Lunch     2
# 220       12.16  2.20    Male    Yes   Fri   Lunch     2
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 49        18.04  3.00    Male     No   Sun  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3

# %% [markdown]
# ### numerical columns<br>
# 1.total_bill<br>
# 2.tips<br>
# 3.size

# %% [markdown]
# ### categorical columns<br>
# 1.sex<br>
# 2.smoker<br>
# 3.day<br>
# 4.time<br>

# %%
iris.sample(5)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 98  99            5.1           2.5            3.0           1.1
# 78  79            6.0           2.9            4.5           1.5
# 1    2            4.9           3.0            1.4           0.2
# 68  69            6.2           2.2            4.5           1.5
# 81  82            5.5           2.4            3.7           1.0
#
#             Species
# 98  Iris-versicolor
# 78  Iris-versicolor
# 1       Iris-setosa
# 68  Iris-versicolor
# 81  Iris-versicolor

# %% [markdown]
# ### numerical columns<br>
# 1.sepal_Length<br>
# 2.sepal_width<br>
# 3.Petal_lenght<br>
# 4.Petal_width

# %% [markdown]
# ### Categorical columns<br>
# '
# 1.Species

# %% [markdown]
# # Plot Different type of Graph

# %% [markdown]
# ## 1.Scatterplot(Numerical-Numerical)

# %%
#Bivariate Analysis
sns.relplot(data=tips,x='total_bill',y='tip',kind='scatter')

# %%
#Multivariate Analysis
sns.relplot(data=tips,x='total_bill',y='tip',hue='sex',style='smoker',size='time')

# %% [markdown]
# ## 2.Barplot(Numerical-Categorical)

# %% [markdown]
# # 3.Displot(Numerical-Categorical)

# %%
sns.displot(data=tips,x='total_bill',kind='kde',hue='sex',fill=True)
# Out:
# C:\Users\narendra tekale\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\narendra tekale\anaconda3\lib\site-packages\seaborn\_oldcore.py:1057: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_data = data.groupby(
# C:\Users\narendra tekale\anaconda3\lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
pip install pandas.profilling
